# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df=pd.read_csv('linear.csv')
df
# Out:
#    Hours_Studied  Exam_Score
# 0              1          35
# 1              2          40
# 2              3          50
# 3              4          55
# 4              5          65
# 5              6          70
# 6              7          75
# 7              8          80
# 8              9          88
# 9             10          95

# %%
x=df[["Hours_Studied"]]
x
y=df[["Exam_Score"]]
y
# Out:
#    Exam_Score
# 0          35
# 1          40
# 2          50
# 3          55
# 4          65
# 5          70
# 6          75
# 7          80
# 8          88
# 9          95

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %%
x_train
# Out:
#    Hours_Studied
# 5              6
# 0              1
# 7              8
# 2              3
# 9             10
# 4              5
# 3              4
# 6              7

# %%
y_train
# Out:
#    Exam_Score
# 5          70
# 0          35
# 7          80
# 2          50
# 9          95
# 4          65
# 3          55
# 6          75

# %%
x_test
# Out:
#    Hours_Studied
# 8              9
# 1              2

# %%
y_test
# Out:
#    Exam_Score
# 8          88
# 1          40

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model.predict(x_test)
y_test_pred
# Out:
# array([[88.40517241],
#        [42.84482759]])

# %%
new_hours = 12
predicted_score = model.predict([[new_hours]])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f"Prediction for {new_hours} study hours = {predicted_score[0].item():.2f}")
# Out:
# Prediction for 12 study hours = 107.93

# %%
x_range = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
y_pred = model.predict(x_range)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x, y, color="blue")

# Regression line
plt.plot(x_range, y_pred, color="red", linewidth=2)
# Labeling
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Linear Regression: Hours vs Exam Score")
plt.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20888\1514806950.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
