# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df=pd.read_csv('linear.csv')
df
# Out:
#    Hours_Studied  Exam_Score
# 0              1          35
# 1              2          40
# 2              3          50
# 3              4          55
# 4              5          65
# 5              6          70
# 6              7          75
# 7              8          80
# 8              9          88
# 9             10          95

# %%
x=df[["Hours_Studied"]]
x
y=df[["Exam_Score"]]
y
# Out:
#    Exam_Score
# 0          35
# 1          40
# 2          50
# 3          55
# 4          65
# 5          70
# 6          75
# 7          80
# 8          88
# 9          95

# %%
x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42
)

# %%
x_train
# Out:
#    Hours_Studied
# 5              6
# 0              1
# 7              8
# 2              3
# 9             10
# 4              5
# 3              4
# 6              7

# %%
y_train
# Out:
#    Exam_Score
# 5          70
# 0          35
# 7          80
# 2          50
# 9          95
# 4          65
# 3          55
# 6          75

# %%
x_test
# Out:
#    Hours_Studied
# 8              9
# 1              2

# %%
y_test
# Out:
#    Exam_Score
# 8          88
# 1          40

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model.predict(x_test)
y_test_pred
# Out:
# array([[88.40517241],
#        [42.84482759]])

# %%
new_hours = 12
predicted_score = model.predict([[new_hours]])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f"Prediction for {new_hours} study hours = {predicted_score[0].item():.2f}")
# Out:
# Prediction for 12 study hours = 107.93

# %%
x_range = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
y_pred = model.predict(x_range)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x_range
# Out:
# array([[ 1.        ],
#        [ 1.09090909],
#        [ 1.18181818],
#        [ 1.27272727],
#        [ 1.36363636],
#        [ 1.45454545],
#        [ 1.54545455],
#        [ 1.63636364],
#        [ 1.72727273],
#        [ 1.81818182],
#        [ 1.90909091],
#        [ 2.        ],
#        [ 2.09090909],
#        [ 2.18181818],
#        [ 2.27272727],
#        [ 2.36363636],
#        [ 2.45454545],
#        [ 2.54545455],
#        [ 2.63636364],
#        [ 2.72727273],
#        [ 2.81818182],
#        [ 2.90909091],
#        [ 3.        ],
#        [ 3.09090909],
#        [ 3.18181818],
#        [ 3.27272727],
#        [ 3.36363636],
#        [ 3.45454545],
#        [ 3.54545455],
#        [ 3.63636364],
#        [ 3.72727273],
#        [ 3.81818182],
#        [ 3.90909091],
#        [ 4.        ],
#        [ 4.09090909],
#        [ 4.18181818],
#        [ 4.27272727],
#        [ 4.36363636],
#        [ 4.45454545],
#        [ 4.54545455],
#        [ 4.63636364],
#        [ 4.72727273],
#        [ 4.81818182],
#        [ 4.90909091],
#        [ 5.        ],
#        [ 5.09090909],
#        [ 5.18181818],
#        [ 5.27272727],
#        [ 5.36363636],
#        [ 5.45454545],
#        [ 5.54545455],
#        [ 5.63636364],
#        [ 5.72727273],
#        [ 5.81818182],
#        [ 5.90909091],
#        [ 6.        ],
#        [ 6.09090909],
#        [ 6.18181818],
#        [ 6.27272727],
#        [ 6.36363636],
#        [ 6.45454545],
#        [ 6.54545455],
#        [ 6.63636364],
#        [ 6.72727273],
#        [ 6.81818182],
#        [ 6.90909091],
#        [ 7.        ],
#        [ 7.09090909],
#        [ 7.18181818],
#        [ 7.27272727],
#        [ 7.36363636],
#        [ 7.45454545],
#        [ 7.54545455],
#        [ 7.63636364],
#        [ 7.72727273],
#        [ 7.81818182],
#        [ 7.90909091],
#        [ 8.        ],
#        [ 8.09090909],
#        [ 8.18181818],
#        [ 8.27272727],
#        [ 8.36363636],
#        [ 8.45454545],
#        [ 8.54545455],
#        [ 8.63636364],
#        [ 8.72727273],
#        [ 8.81818182],
#        [ 8.90909091],
#        [ 9.        ],
#        [ 9.09090909],
#        [ 9.18181818],
#        [ 9.27272727],
#        [ 9.36363636],
#        [ 9.45454545],
#        [ 9.54545455],
#        [ 9.63636364],
#        [ 9.72727273],
#        [ 9.81818182],
#        [ 9.90909091],
#        [10.        ]])

# %%
y_pred
# Out:
# array([[36.3362069 ],
#        [36.92789969],
#        [37.51959248],
#        [38.11128527],
#        [38.70297806],
#        [39.29467085],
#        [39.88636364],
#        [40.47805643],
#        [41.06974922],
#        [41.66144201],
#        [42.2531348 ],
#        [42.84482759],
#        [43.43652038],
#        [44.02821317],
#        [44.61990596],
#        [45.21159875],
#        [45.80329154],
#        [46.39498433],
#        [46.98667712],
#        [47.57836991],
#        [48.1700627 ],
#        [48.76175549],
#        [49.35344828],
#        [49.94514107],
#        [50.53683386],
#        [51.12852665],
#        [51.72021944],
#        [52.31191223],
#        [52.90360502],
#        [53.49529781],
#        [54.0869906 ],
#        [54.67868339],
#        [55.27037618],
#        [55.86206897],
#        [56.45376176],
#        [57.04545455],
#        [57.63714734],
#        [58.22884013],
#        [58.82053292],
#        [59.41222571],
#        [60.0039185 ],
#        [60.59561129],
#        [61.18730408],
#        [61.77899687],
#        [62.37068966],
#        [62.96238245],
#        [63.55407524],
#        [64.14576803],
#        [64.73746082],
#        [65.32915361],
#        [65.92084639],
#        [66.51253918],
#        [67.10423197],
#        [67.69592476],
#        [68.28761755],
#        [68.87931034],
#        [69.47100313],
#        [70.06269592],
#        [70.65438871],
#        [71.2460815 ],
#        [71.83777429],
#        [72.42946708],
#        [73.02115987],
#        [73.61285266],
#        [74.20454545],
#        [74.79623824],
#        [75.38793103],
#        [75.97962382],
#        [76.57131661],
#        [77.1630094 ],
#        [77.75470219],
#        [78.34639498],
#        [78.93808777],
#        [79.52978056],
#        [80.12147335],
#        [80.71316614],
#        [81.30485893],
#        [81.89655172],
#        [82.48824451],
#        [83.0799373 ],
#        [83.67163009],
#        [84.26332288],
#        [84.85501567],
#        [85.44670846],
#        [86.03840125],
#        [86.63009404],
#        [87.22178683],
#        [87.81347962],
#        [88.40517241],
#        [88.9968652 ],
#        [89.58855799],
#        [90.18025078],
#        [90.77194357],
#        [91.36363636],
#        [91.95532915],
#        [92.54702194],
#        [93.13871473],
#        [93.73040752],
#        [94.32210031],
#        [94.9137931 ]])

# %%
plt.scatter(x,y, color='blue')
plt.plot(x_range, y_pred, color='red')
plt.xlabel("Hour")
plt.ylabel("score")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x, y, color="blue")

# Regression line
plt.plot(x_range, y_pred, color="red", linewidth=2)
# Labeling
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Linear Regression: Hours vs Exam Score")
plt.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9416\1514806950.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
